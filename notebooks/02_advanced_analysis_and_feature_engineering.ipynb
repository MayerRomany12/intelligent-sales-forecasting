# %% [markdown]
# # Milestone 2: Advanced Data Analysis and Feature Engineering
#
# In this notebook, we will:
# 1. Perform time series analysis on the sales data.
# 2. Create time series specific features (lag, rolling averages).
# 3. Check for stationarity.
