# %% [markdown]
# # Milestone 1: Data Collection, Exploration, and Preprocessing
#
# In this notebook, we will explore the Olist dataset and prepare it for forecasting.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os
sys.path.append(os.path.abspath('../'))

from src.data_preprocessing import load_and_merge_datasets, clean_data, aggregate_time_series

sns.set_theme(style="whitegrid")

# %% [markdown]
# ## 1. Load and Merge Data

# %%
raw_data_dir = '../data/raw'
merged_df = load_and_merge_datasets(raw_data_dir)
merged_df.head(20)
# Out:
# Loading datasets...
# Merging datasets...
#                             order_id  order_item_id  \
# 0   00010242fe8c5a6d1ba2dd792cb16214              1
# 1   00018f77f2f0320c557190d7a144bdd3              1
# 2   000229ec398224ef6ca0657da4fc703e              1
# 3   00024acbcdf0a6daa1e931b038114c75              1
# 4   00042b26cf59d7ce69dfabb4e55b4fd9              1
# 5   00048cc3ae777c65dbb7d2a0634bc1ea              1
# 6   00054e8431b9d7675808bcb819fb4a32              1
# 7   000576fe39319847cbb9d288c5617fa6              1
# 8   0005a1a1728c9d785b8e2b08b904576c              1
# 9   0005f50442cb953dcd1d21e1fb923495              1
# 10  00061f2a7bc09da83e415a52dc8a4af1              1
# 11  00063b381e2406b52ad429470734ebd5              1
# 12  0006ec9db01a64e59a68b2c340bf65a7              1
# 13  0008288aa423d2a3f00fcb17cd7d8719              1
# 14  0008288aa423d2a3f00fcb17cd7d8719              2
# 15  0009792311464db532ff765bf7b182ae              1
# 16  0009c9a17f916a706d71784483a5d643              1
# 17  000aed2e25dbad2f9ddb70584c5a2ded              1
# 18  000c3e6612759851cc3cbb4b83257986              1
# 19  000e562887b1f2006d75e0be9558292e              1
#
#                           product_id                         seller_id  \
# 0   4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1   e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2   c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3   7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4   ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
# 5   ef92defde845ab8450f9d70c526ef70f  6426d21aca402a131fc0a5d0960a3c90
# 6   8d4f2bb7e93e6710a28f34fa83ee7d28  7040e82f899a04d1b434b795a43b4617
# 7   557d850972a7d6f792fd18ae1400d9b6  5996cddab893a4652a15592fb58ab8db
# 8   310ae3c140ff94b03219ad0adc3c778f  a416b6a846a11724393025641d4edd5e
# 9   4535b0e1091c278dfd193e5a1d63b39f  ba143b05f0110f0dc71ad71b4466ce92
# 10  d63c1011f49d98b976c352955b1c4bea  cc419e0650a3c5ba77189a1882b7556a
# 11  f177554ea93259a5b282f24e33f65ab6  8602a61d680a10a82cceeeda0d99ea3d
# 12  99a4788cb24856965c36a24e339b6058  4a3ca9315b744ce9f8e9374361493884
# 13  368c6c730842d78016ad823897a372db  1f50f920176fa81dab994f9023523100
# 14  368c6c730842d78016ad823897a372db  1f50f920176fa81dab994f9023523100
# 15  8cab8abac59158715e0d70a36c807415  530ec6109d11eaaf87999465c6afee01
# 16  3f27ac8e699df3d300ec4a5d8c5cf0b2  fcb5ace8bcc92f75707dc0f01a27d269
# 17  4fa33915031a8cde03dd0d3e8fb27f01  fe2032dab1a61af8794248c8196565c9
# 18  b50c950aba0dcead2c48032a690ce817  218d46b86c1881d022bce9c68a7d4b15
# 19  5ed9eaf534f6936b51d0b6c5e4d5c2e9  8cbac7e12637ed9cffa18c7875207478
#
#     shipping_limit_date   price  freight_value        product_category_name  \
# 0   2017-09-19 09:45:35   58.90          13.29                   cool_stuff
# 1   2017-05-03 11:05:13  239.90          19.93                     pet_shop
# 2   2018-01-18 14:48:30  199.00          17.87             moveis_decoracao
# 3   2018-08-15 10:10:18   12.99          12.79                   perfumaria
# 4   2017-02-13 13:57:51  199.90          18.14           ferramentas_jardim
# 5   2017-05-23 03:55:27   21.90          12.69        utilidades_domesticas
# 6   2017-12-14 12:10:31   19.90          11.85                    telefonia
# 7   2018-07-10 12:30:45  810.00          70.75           ferramentas_jardim
# 8   2018-03-26 18:31:29  145.95          11.65                 beleza_saude
# 9   2018-07-06 14:10:56   53.99          11.40              livros_tecnicos
# 10  2018-03-29 22:28:09   59.99           8.88                 beleza_saude
# 11  2018-07-31 17:30:39   45.00          12.98  fashion_bolsas_e_acessorios
# 12  2018-07-26 17:24:20   74.00          23.32              cama_mesa_banho
# 13  2018-02-21 02:55:52   49.90          13.37           ferramentas_jardim
# 14  2018-02-21 02:55:52   49.90          13.37           ferramentas_jardim
# 15  2018-08-17 12:15:10   99.90          27.65                esporte_lazer
# 16  2018-05-02 09:31:53  639.00          11.34               consoles_games
# 17  2018-05-16 20:57:03  144.00           8.77                   perfumaria
# 18  2017-08-21 03:33:13   99.00          13.71                esporte_lazer
# 19  2018-02-28 12:08:37   25.00          16.11                   cool_stuff
#
#     product_name_lenght  product_description_lenght  ...  product_height_cm  \
# 0                  58.0                       598.0  ...                9.0
# 1                  56.0                       239.0  ...               30.0
# 2                  59.0                       695.0  ...               13.0
# 3                  42.0                       480.0  ...               10.0
# 4                  59.0                       409.0  ...               40.0
# 5                  36.0                       558.0  ...                8.0
# 6                  52.0                       815.0  ...                5.0
# 7                  39.0                      1310.0  ...               75.0
# 8                  59.0                       493.0  ...               12.0
# 9                  52.0                      1192.0  ...                3.0
# 10                 57.0                       614.0  ...               25.0
# 11                 35.0                        60.0  ...               16.0
# 12                 54.0                       245.0  ...               10.0
# 13                 57.0                       366.0  ...               22.0
# 14                 57.0                       366.0  ...               22.0
# 15                 56.0                      1392.0  ...               20.0
# 16                 37.0                      1172.0  ...                5.0
# 17                 43.0                       116.0  ...               18.0
# 18                 58.0                      2584.0  ...               16.0
# 19                 51.0                       693.0  ...               20.0
#
#     product_width_cm  product_category_name_english  \
# 0               14.0                     cool_stuff
# 1               40.0                       pet_shop
# 2               33.0                furniture_decor
# 3               15.0                      perfumery
# 4               30.0                   garden_tools
# 5               15.0                     housewares
# 6               20.0                      telephony
# 7               45.0                   garden_tools
# 8               16.0                  health_beauty
# 9               21.0                books_technical
# 10              20.0                  health_beauty
# 11              11.0       fashion_bags_accessories
# 12              40.0                 bed_bath_table
# 13              30.0                   garden_tools
# 14              30.0                   garden_tools
# 15              30.0                 sports_leisure
# 16              12.0                 consoles_games
# 17              19.0                      perfumery
# 18              16.0                 sports_leisure
# 19              21.0                     cool_stuff
#
#                          customer_id  order_status order_purchase_timestamp  \
# 0   3ce436f183e68e07877b285a838db11a     delivered      2017-09-13 08:59:02
# 1   f6dd3ec061db4e3987629fe6b26e5cce     delivered      2017-04-26 10:53:06
# 2   6489ae5e4333f3693df5ad4372dab6d3     delivered      2018-01-14 14:33:31
# 5            2017-05-22 13:44:35           2017-06-06 00:00:00
# 6            2017-12-18 22:03:38           2018-01-04 00:00:00
# 7            2018-07-09 14:04:07           2018-07-25 00:00:00
# 8            2018-03-29 18:17:31           2018-03-29 00:00:00
# 9            2018-07-04 17:28:31           2018-07-23 00:00:00
# 10           2018-03-29 00:04:19           2018-04-09 00:00:00
# 11           2018-08-07 13:56:52           2018-08-07 00:00:00
# 12           2018-07-31 01:04:15           2018-08-22 00:00:00
# 13           2018-02-26 13:55:22           2018-03-06 00:00:00
# 14           2018-02-26 13:55:22           2018-03-06 00:00:00
# 15           2018-08-22 12:02:27           2018-08-28 00:00:00
# 16           2018-04-30 17:54:25           2018-05-09 00:00:00
# 17           2018-05-18 16:46:31           2018-05-22 00:00:00
# 18           2017-08-19 15:22:17           2017-09-01 00:00:00
# 19           2018-03-12 18:46:34           2018-03-19 00:00:00
#
# [20 rows x 23 columns]

# %% [markdown]
# ## 2. Data Cleaning

# %%
cleaned_df = clean_data(merged_df)
cleaned_df.info()
# Out:
# Cleaning data...
# <class 'pandas.DataFrame'>
# Index: 112101 entries, 0 to 112649
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112101 non-null  str
#  1   order_item_id                  112101 non-null  int64
#  2   product_id                     112101 non-null  str
#  3   seller_id                      112101 non-null  str
#  4   shipping_limit_date            112101 non-null  str
#  5   price                          112101 non-null  float64
#  6   freight_value                  112101 non-null  float64
#  7   product_category_name          110512 non-null  str
#  8   product_name_lenght            110512 non-null  float64
#  9   product_description_lenght     110512 non-null  float64
#  10  product_photos_qty             110512 non-null  float64
#  11  product_weight_g               112083 non-null  float64
#  12  product_length_cm              112083 non-null  float64
#  13  product_height_cm              112083 non-null  float64
#  14  product_width_cm               112083 non-null  float64
#  15  product_category_name_english  112101 non-null  str
#  16  customer_id                    112101 non-null  str
#  17  order_status                   112101 non-null  str
#  18  order_purchase_timestamp       112101 non-null  datetime64[us]
#  19  order_approved_at              112086 non-null  str
#  20  order_delivered_carrier_date   111380 non-null  str
#  21  order_delivered_customer_date  110189 non-null  str
#  22  order_estimated_delivery_date  112101 non-null  str
# dtypes: datetime64[us](1), float64(9), int64(1), str(12)
# memory usage: 48.4 MB

# %% [markdown]
# ## 3. Exploratory Data Analysis (EDA)
# Let's look at the top selling product categories.

# %%
top_categories = cleaned_df.groupby('product_category_name_english')['price'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_categories.values, y=top_categories.index, palette='viridis')
plt.title('Top 10 Product Categories by Revenue')
plt.xlabel('Total Revenue')
plt.ylabel('Category')
plt.show()

# %% [markdown]
# ## 4. Aggregate to Time Series
# We aggregate the data into a daily frequency to forecast daily sales.

# %%
ts_df = aggregate_time_series(cleaned_df, freq='D')
ts_df.head()

# %%
plt.figure(figsize=(15, 6))
plt.plot(ts_df.index, ts_df['total_sales'], label='Daily Sales', color='blue')
plt.title('Daily Total Sales (Revenue) Over Time')
plt.xlabel('Date')
plt.ylabel('Total Sales (BRL)')
plt.legend()
plt.show()

# %%
# Save the processed data for Milestone 2
ts_df.to_csv('../data/processed/time_series_sales.csv')
print("Saved time_series_sales.csv")
